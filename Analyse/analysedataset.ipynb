# %%
import pandas as pd
import sys
sys.path.append('..')
from AnalyseDataSet import SpamAnalysis

# %%
SpamAnalysis("../DataSetBrut/DataSmsSpamNH.csv").GraphAnalysis()
# Out:
# Nombre de données : 3935

# %%
SpamAnalysis("../telegram_spam_dataset.csv").GraphAnalysis()
# Out:
# Nombre de données : 20324

# %%
analysis = SpamAnalysis("../DataSetBrut/BD1.txt").GraphAnalysis()
# Out:
# Nombre de données : 5572
